# %%
import uproot

# Open the ROOT file
file = uproot.open("/eos/lhcb/wg/BnoC/Bu2LambdaPPP/MC/PIDCorrection/MC18MDBu2L0barPKpPim_B2L0barPKpPimLine_DD_PIDCorr.root")

# List all top-level directories (TDirectoryFiles)
for key in file.keys():
    print(key)
# Out:
# DecayTree;1

# %%
tree = file["DecayTree"]
for key in tree.keys():
    print(key)
# Out:
# Bu_DOCA12
# Bu_ETA
# Bu_MAXDOCA
# Bu_Y
# Bu_ENDVERTEX_X
# Bu_ENDVERTEX_Y
# Bu_ENDVERTEX_Z
# Bu_ENDVERTEX_XERR
# Bu_ENDVERTEX_YERR
# Bu_ENDVERTEX_ZERR
# Bu_ENDVERTEX_CHI2
# Bu_ENDVERTEX_NDOF
# Bu_ENDVERTEX_COV_
# Bu_OWNPV_X
# Bu_OWNPV_Y
# Bu_OWNPV_Z
# Bu_OWNPV_XERR
# Bu_OWNPV_YERR
# Bu_OWNPV_ZERR
# Bu_OWNPV_CHI2
# Bu_OWNPV_NDOF
# Bu_OWNPV_COV_
# Bu_IP_OWNPV
# Bu_IPCHI2_OWNPV
# Bu_FD_OWNPV
# Bu_FDCHI2_OWNPV
# Bu_DIRA_OWNPV
# Bu_P
# Bu_PT
# Bu_PE
# Bu_PX
# Bu_PY
# Bu_PZ
# Bu_MM
# Bu_MMERR
# Bu_M
# Bu_TRUEID
# Bu_MC_MOTHER_ID
# Bu_MC_MOTHER_KEY
# Bu_MC_GD_MOTHER_ID
# Bu_MC_GD_MOTHER_KEY
# Bu_MC_GD_GD_MOTHER_ID
# Bu_MC_GD_GD_MOTHER_KEY
# Bu_TRUEP_E
# Bu_TRUEP_X
# Bu_TRUEP_Y
# Bu_TRUEP_Z
# Bu_TRUEPT
# Bu_TRUEORIGINVERTEX_X
# Bu_TRUEORIGINVERTEX_Y
# Bu_TRUEORIGINVERTEX_Z
# Bu_TRUEENDVERTEX_X
# Bu_TRUEENDVERTEX_Y
# Bu_TRUEENDVERTEX_Z
# Bu_TRUEISSTABLE
# Bu_TRUETAU
# Bu_Reconstructible
# Bu_Reconstructed
# Bu_ProtoParticles
# nBu_PP_PX
# Bu_PP_PX
# nBu_PP_PY
# Bu_PP_PY
# nBu_PP_PZ
# Bu_PP_PZ
# ...

# %%
directory = file["MC_B2L0barPKpKm"]
print(directory.keys())  # List objects inside the directory
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 directory = file["MC_B2L0barPKpKm"]
#       2 print(directory.keys())  # List objects inside the directory
#
# File /afs/cern.ch/work/m/melashri/public/bu2LpKK/venv/lib/python3.12/site-packages/uproot/reading.py:2116, in ReadOnlyDirectory.__getitem__(self, where)
#    2113     return step
#    2115 else:
# -> 2116     return self.key(where).get()
#
# File /afs/cern.ch/work/m/melashri/public/bu2LpKK/venv/lib/python3.12/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
#    2065         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2066     )
#    2067 else:
#    2068     raise uproot.KeyInFileError(
# ...

# %%
tree = directory["DecayTree"]  # Replace with the actual tree name
for key in tree.keys():
    print(key)
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tree = directory["DecayTree"]  # Replace with the actual tree name
#       2 for key in tree.keys():
#       3     print(key)
#
# File /afs/cern.ch/work/m/melashri/public/bu2LpKK/venv/lib/python3.12/site-packages/uproot/reading.py:2116, in ReadOnlyDirectory.__getitem__(self, where)
#    2113     return step
#    2115 else:
# -> 2116     return self.key(where).get()
#
# File /afs/cern.ch/work/m/melashri/public/bu2LpKK/venv/lib/python3.12/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
#    2065         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2066     )
#    2067 else:
#    2068     raise uproot.KeyInFileError(
# ...
